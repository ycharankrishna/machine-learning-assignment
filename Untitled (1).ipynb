# %%
import pandas as pd

# %%
#add csv file to dataframe
df = pd.read_csv('IRIS.csv')

#create boxplot
boxplot = df.boxplot(figsize = (5,5))
boxplot = df.boxplot(figsize = (5,5), rot = 90, fontsize= '8', grid = False)

# %% [markdown]
# # SCATTER PLOT

# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt

# Load data from a CSV file into a Pandas DataFrame:
dataFrame = pd.read_csv("IRIS.csv")

# plotting scatterplot with Age and Weight (kgs)
# hue parameter set as "Role"
sb.scatterplot(dataFrame['species'],dataFrame['sepal_length'], hue=dataFrame['species'])

plt.ylabel("sepal_length")
plt.show()
# Out:
# c:\users\ychar\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt

# Load data from a CSV file into a Pandas DataFrame:
dataFrame = pd.read_csv("IRIS.csv")

# plotting scatterplot with Age and Weight (kgs)
# hue parameter set as "Role"
sb.scatterplot(dataFrame['species'],dataFrame['sepal_width'], hue=dataFrame['species'])

plt.ylabel("sepal_width")
plt.show()
# Out:
# c:\users\ychar\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt

# Load data from a CSV file into a Pandas DataFrame:
dataFrame = pd.read_csv("IRIS.csv")

# plotting scatterplot with Age and Weight (kgs)
# hue parameter set as "Role"
sb.scatterplot(dataFrame['species'],dataFrame['petal_length'], hue=dataFrame['species'])

plt.ylabel("petal_length")
plt.show()
# Out:
# c:\users\ychar\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt

# Load data from a CSV file into a Pandas DataFrame:
dataFrame = pd.read_csv("IRIS.csv")

# plotting scatterplot with Age and Weight (kgs)
# hue parameter set as "Role"
sb.scatterplot(dataFrame['species'],dataFrame['petal_width'], hue=dataFrame['species'])

plt.ylabel("petal_width")
plt.show()
# Out:
# c:\users\ychar\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt

# Load data from a CSV file into a Pandas DataFrame:
dataFrame = pd.read_csv("IRIS.csv")

# plotting scatterplot with Age and Weight (kgs)
# hue parameter set as "Role"
sb.scatterplot(dataFrame['species'],dataFrame['petal_width'], hue=dataFrame['species'])

plt.ylabel("petal_width")
plt.show()
# Out:
# c:\users\ychar\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
import pandas as pd
 
iris = pd.read_csv("IRIS.csv")
 
# style used as a theme of graph
# for example if we want black
# graph with grid then write "darkgrid"
sns.set_style("whitegrid")
 
# sepal_length, petal_length are iris
# feature data height used to define
# Height of graph whereas hue store the
# class of iris dataset.
sns.FacetGrid(iris, hue ="species",
              height = 6).map(plt.scatter,
                              'sepal_length',
                              'petal_length').add_legend()

# %%
from sklearn.datasets import load_iris
iris = load_iris()
from matplotlib import pyplot as plt
# The indices of the features that we are plotting
x_index = 0
y_index = 1
# this formatter will label the colorbar with the correct target names
formatter = plt.FuncFormatter(lambda i, *args: iris.target_names[int(i)])
plt.figure(figsize=(5, 4))
plt.scatter(iris.data[:, x_index], iris.data[:, y_index], c=iris.target)
plt.colorbar(ticks=[0, 1, 2], format=formatter)
plt.xlabel(iris.feature_names[x_index])
plt.ylabel(iris.feature_names[y_index])

plt.tight_layout()
plt.show()

# %% [markdown]
# # BOX PLOT

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import statistics 
# load the iris data to a dataframe
iris_data = pd.read_csv('IRIS.csv')
# plot parameter set
params = {'legend.fontsize': 9
          , 'font.size': 16
          , 'font.serif': ['Computer Modern Roman']
          , 'axes.labelsize': 16
          , 'xtick.labelsize': 17
          , 'ytick.labelsize': 14
         }
plt.rcParams.update(params)


# comparison between 3 categories for each numerical variable
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(16,5))

ax = sns.boxplot(x="species", y="sepal_length",data=iris_data, palette="Set3", ax = ax1).set_title("Sepal length across species",fontsize=17)
ax = sns.boxplot(x="species", y="sepal_width",data=iris_data, palette="Set3", ax = ax2).set_title("Sepal width across species",fontsize=17)

ax1.set_ylabel('')
ax1.set_xlabel('')

ax2.set_ylabel('')
ax2.set_xlabel('')

# Turn off tick labels
#ax1.set_yticklabels([])
#ax1.set_xticklabels([])

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(16,5))

ax = sns.boxplot(x="species", y="petal_length",data=iris_data, palette="Set3", ax = ax1).set_title("Petal length across species",fontsize=17)
ax = sns.boxplot(x="species", y="petal_width",data=iris_data, palette="Set3", ax = ax2).set_title("Petal width across species",fontsize=17)

ax1.set_ylabel('')
ax1.set_xlabel('')

ax2.set_ylabel('')
ax2.set_xlabel('')

plt.show()

# %%
# importing modules
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # library for creating visualizations
import seaborn as sns # library for making statistical graphics. Built on top of matplotlib
import statistics # calculating statistics of numeric data

# load the iris data to a dataframe
iris_data = pd.read_csv('IRIS.csv')

# plot parameter set
params = {'legend.fontsize': 9
          , 'font.size': 16
          , 'font.serif': ['Computer Modern Roman']
          , 'axes.labelsize': 16
          , 'xtick.labelsize': 14
          , 'ytick.labelsize': 14
          , 'figure.figsize' : (7,5)
         }
plt.rcParams.update(params)


# Comparison between 4 numeric variables for each category

iris_setosa = iris_data[iris_data['species'] == 'Iris-setosa']
iris_virginica = iris_data[iris_data['species'] == 'Iris-virginica']
iris_versicolor = iris_data[iris_data['species'] == 'Iris-versicolor']

ax = sns.boxplot(data=iris_setosa, orient="v", palette="Set3").set_title("Iris setosa",fontsize=15)
plt.show()

ax = sns.boxplot(data=iris_virginica, orient="v",palette="Set3").set_title("Iris virginica",fontsize=15)
plt.show()

ax = sns.boxplot(data=iris_versicolor, orient="v",palette="Set3").set_title("Iris versicolor",fontsize=15)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score

sns.set_style("darkgrid")
# %matplotlib inline

# %%
from sklearn.datasets import load_iris

data = load_iris()
cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

feature_set = pd.DataFrame(data.data, columns=cols)

species = pd.Series(data.target, name="species").map({
    0: 'Iris-setosa',
    1: 'Iris-versicolor',
    2: 'Iris-virginica'
})
iris_data = pd.merge(feature_set, species, left_index=True, right_index=True)

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# check class distribution

_ = sns.countplot(iris_data.species)
_ = plt.title("Class distribution => Balanced Dataset", fontsize=14)
# Out:
# c:\users\ychar\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # CENTRAL TENDENCY AND DATA DESPRESSION

# %%
iris_setosa = iris_data.loc[iris_data.species == "Iris-setosa"]
iris_versicolor = iris_data.loc[iris_data.species == "Iris-versicolor"]
iris_virginica = iris_data.loc[iris_data.species == "Iris-virginica"]

# %%
print("Setosa mean: ", np.mean(iris_setosa['petal_length']))
print("Setosa corrupted mean: ", np.mean(np.append(iris_setosa['petal_length'], 50)))
print("versicolor mean: ", np.mean(iris_versicolor['petal_length']))
print("virginica mean: ",  np.mean(iris_virginica['petal_length']))
print()
print("Setosa variance: ", np.var(iris_setosa['petal_length']))
print("Setosa corrupted variance: ", np.var(np.append(iris_setosa['petal_length'], 50)))
print("versicolor variance: ", np.var(iris_versicolor['petal_length']))
print("virginica variance: ", np.var(iris_virginica['petal_length']))
print() 
print("Setosa std: ", np.std(iris_setosa['petal_length']))
print("Setosa corrupted std: ", np.std(np.append(iris_setosa['petal_length'], 50)))
print("versicolor std: ", np.std(iris_versicolor['petal_length']))
print("virginica std: ", np.std(iris_virginica['petal_length']))
# Out:
# Setosa mean:  1.4620000000000002
# Setosa corrupted mean:  2.4137254901960787
# versicolor mean:  4.26
# virginica mean:  5.5520000000000005
#
# Setosa variance:  0.029555999999999995
# Setosa corrupted variance:  45.31804690503652
# versicolor variance:  0.21640000000000004
# virginica variance:  0.29849600000000004
#
# Setosa std:  0.17191858538273283
# Setosa corrupted std:  6.731868010072429
# versicolor std:  0.4651881339845203
# virginica std:  0.546347874526844

# %%
print("Median: ")
print("Setosa Median: ", np.median(iris_setosa['petal_length']))
print("Setosa corrupted Median: ", np.median(np.append(iris_setosa['petal_length'], 50)))
print("versicolor Median: ", np.median(iris_versicolor['petal_length']))
print("virginica Median: ",  np.median(iris_virginica['petal_length']))
print("\nQuantiles: [0, 25, 50, 75]")
print("Setosa Quantile: ", np.percentile(iris_setosa['petal_length'], np.arange(0, 100, 25)))
print("Setosa corrupted Quantile: ", np.percentile(np.append(iris_setosa['petal_length'], 50), np.arange(0, 100, 25)))
print("versicolor Quantile: ", np.percentile(iris_versicolor['petal_length'], np.arange(0, 100, 25)))
print("virginica Quantile: ", np.percentile(iris_virginica['petal_length'], np.arange(0, 100, 25)))
print("\n90th Percentiles")
print("Setosa Percentile: ", np.percentile(iris_setosa['petal_length'], 90))
print("Setosa corrupted Percentile: ", np.percentile(np.append(iris_setosa['petal_length'], 50), 90))
print("versicolor Percentile: ", np.percentile(iris_versicolor['petal_length'], 90))
print("virginica Percentile: ", np.percentile(iris_virginica['petal_length'], 90))
from statsmodels import robust
print("\nMedian Absolute Deviation")
print("Setosa MAD: ", robust.mad(iris_setosa['petal_length']))
print("Setosa corrupted MAD: ", robust.mad(np.append(iris_setosa['petal_length'], 50)))
print("versicolor MAD: ", robust.mad(iris_versicolor['petal_length']))
print("virginica MAD: ", robust.mad(iris_virginica['petal_length']))
# Out:
# Median:
# Setosa Median:  1.5
# Setosa corrupted Median:  1.5
# versicolor Median:  4.35
# virginica Median:  5.55
#
# Quantiles: [0, 25, 50, 75]
# Setosa Quantile:  [1.    1.4   1.5   1.575]
# Setosa corrupted Quantile:  [1.  1.4 1.5 1.6]
# versicolor Quantile:  [3.   4.   4.35 4.6 ]
# virginica Quantile:  [4.5   5.1   5.55  5.875]
#
# 90th Percentiles
# Setosa Percentile:  1.7
# Setosa corrupted Percentile:  1.7
# versicolor Percentile:  4.8
# virginica Percentile:  6.31
#
# Median Absolute Deviation
# Setosa MAD:  0.14826022185056031
# Setosa corrupted MAD:  0.14826022185056031
# versicolor MAD:  0.5189107764769602
# virginica MAD:  0.6671709983275211

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score
iris_data = pd.read_csv('IRIS.csv')
plt.figure(figsize=(25,15))    
for i, j in enumerate(iris_data.columns[:-1], 1):
    plt.subplot(2, 2, i)
    _ = sns.boxplot(x="species", y=f"{j}", data=iris_data)
    _ = sns.stripplot(x="species", y=f"{j}", data=iris_data,  jitter=True, dodge=True, linewidth=1)
    _ = plt.title("Box Plot")

# %%
# experimenting

def simple_rule(subset):
    cls = []
    for idx, row in subset.iterrows():
        if row['petal_length'] <= 2:
            cls.append("Iris-setosa")
        elif row['petal_length'] > 2 and row['petal_length'] <=4.6:
            cls.append("Iris-versicolor")
        else:
            cls.append("Iris-virginica")
    # accuracy
    cls = np.array(cls)
        
    return accuracy_score(cls, subset.species.values)

# %%
iris_data.sample(frac=1)

random_idx = np.random.choice(range(0, 150), 20)
simple_rule(iris_data.sample(frac=1).iloc[random_idx])
# Out:
# 0.85

# %%
plt.figure(figsize=(8, 6))
_ = sns.heatmap(iris_data.corr(), vmin=-1, vmax=1, annot=True, cmap='afmhot')

# %%
_ = sns.relplot(x='petal_length', y='petal_width', hue='species', data=iris_data, height=7)
_ = plt.title("Scatter plot", fontsize=14)

# %%
_ = sns.relplot(x='sepal_length', y='sepal_width', hue='species', data=iris_data, height=7)
_ = plt.title("Scatter plot", fontsize=14)

# %%
print("Setosa mean: ", np.mean(iris_setosa['sepal_length']))
print("Setosa corrupted mean: ", np.mean(np.append(iris_setosa['sepal_length'], 50)))
print("versicolor mean: ", np.mean(iris_versicolor['sepal_length']))
print("virginica mean: ",  np.mean(iris_virginica['sepal_length']))
print()
print("Setosa variance: ", np.var(iris_setosa['sepal_length']))
print("Setosa corrupted variance: ", np.var(np.append(iris_setosa['sepal_length'], 50)))
print("versicolor variance: ", np.var(iris_versicolor['sepal_length']))
print("virginica variance: ", np.var(iris_virginica['sepal_length']))
print() 
print("Setosa std: ", np.std(iris_setosa['sepal_length']))
print("Setosa corrupted std: ", np.std(np.append(iris_setosa['sepal_length'], 50)))
print("versicolor std: ", np.std(iris_versicolor['sepal_length']))
print("virginica std: ", np.std(iris_virginica['sepal_length']))
print("Median: ")
print("Setosa Median: ", np.median(iris_setosa['sepal_length']))
print("Setosa corrupted Median: ", np.median(np.append(iris_setosa['sepal_length'], 50)))
print("versicolor Median: ", np.median(iris_versicolor['sepal_length']))
print("virginica Median: ",  np.median(iris_virginica['sepal_length']))
print("\nQuantiles: [0, 25, 50, 75]")
print("Setosa Quantile: ", np.percentile(iris_setosa['sepal_length'], np.arange(0, 100, 25)))
print("Setosa corrupted Quantile: ", np.percentile(np.append(iris_setosa['sepal_length'], 50), np.arange(0, 100, 25)))
print("versicolor Quantile: ", np.percentile(iris_versicolor['sepal_length'], np.arange(0, 100, 25)))
print("virginica Quantile: ", np.percentile(iris_virginica['sepal_length'], np.arange(0, 100, 25)))
print("\n90th Percentiles")
print("Setosa Percentile: ", np.percentile(iris_setosa['sepal_length'], 90))
print("Setosa corrupted Percentile: ", np.percentile(np.append(iris_setosa['sepal_length'], 50), 90))
print("versicolor Percentile: ", np.percentile(iris_versicolor['sepal_length'], 90))
print("virginica Percentile: ", np.percentile(iris_virginica['petal_length'], 90))
from statsmodels import robust
print("\nMedian Absolute Deviation")
print("Setosa MAD: ", robust.mad(iris_setosa['sepal_length']))
print("Setosa corrupted MAD: ", robust.mad(np.append(iris_setosa['sepal_length'], 50)))
print("versicolor MAD: ", robust.mad(iris_versicolor['sepal_length']))
print("virginica MAD: ", robust.mad(iris_virginica['sepal_length']))
# Out:
# Setosa mean:  5.006
# Setosa corrupted mean:  5.8882352941176475
# versicolor mean:  5.936
# virginica mean:  6.587999999999998
#
# Setosa variance:  0.12176400000000002
# Setosa corrupted variance:  39.03633217993079
# versicolor variance:  0.261104
# virginica variance:  0.3962560000000001
#
# Setosa std:  0.3489469873777391
# Setosa corrupted std:  6.247906223682522
# versicolor std:  0.5109833656783751
# virginica std:  0.6294886813914926
# Median:
# Setosa Median:  5.0
# Setosa corrupted Median:  5.0
# versicolor Median:  5.9
# virginica Median:  6.5
#
# Quantiles: [0, 25, 50, 75]
# Setosa Quantile:  [4.3 4.8 5.  5.2]
# Setosa corrupted Quantile:  [4.3 4.8 5.  5.2]
# versicolor Quantile:  [4.9 5.6 5.9 6.3]
# virginica Quantile:  [4.9   6.225 6.5   6.9  ]
#
# 90th Percentiles
# Setosa Percentile:  5.41
# Setosa corrupted Percentile:  5.5
# versicolor Percentile:  6.7
# virginica Percentile:  6.31
#
# Median Absolute Deviation
# Setosa MAD:  0.29652044370112063
# ...

# %%
print("Setosa mean: ", np.mean(iris_setosa['sepal_width']))
print("Setosa corrupted mean: ", np.mean(np.append(iris_setosa['sepal_width'], 50)))
print("versicolor mean: ", np.mean(iris_versicolor['sepal_width']))
print("virginica mean: ",  np.mean(iris_virginica['sepal_width']))
print()
print("Setosa variance: ", np.var(iris_setosa['sepal_width']))
print("Setosa corrupted variance: ", np.var(np.append(iris_setosa['sepal_width'], 50)))
print("versicolor variance: ", np.var(iris_versicolor['sepal_width']))
print("virginica variance: ", np.var(iris_virginica['sepal_width']))
print() 
print("Setosa std: ", np.std(iris_setosa['sepal_width']))
print("Setosa corrupted std: ", np.std(np.append(iris_setosa['sepal_width'], 50)))
print("versicolor std: ", np.std(iris_versicolor['sepal_width']))
print("virginica std: ", np.std(iris_virginica['sepal_width']))
print("Median: ")
print("Setosa Median: ", np.median(iris_setosa['sepal_width']))
print("Setosa corrupted Median: ", np.median(np.append(iris_setosa['sepal_width'], 50)))
print("versicolor Median: ", np.median(iris_versicolor['sepal_width']))
print("virginica Median: ",  np.median(iris_virginica['sepal_width']))
print("\nQuantiles: [0, 25, 50, 75]")
print("Setosa Quantile: ", np.percentile(iris_setosa['sepal_width'], np.arange(0, 100, 25)))
print("Setosa corrupted Quantile: ", np.percentile(np.append(iris_setosa['sepal_width'], 50), np.arange(0, 100, 25)))
print("versicolor Quantile: ", np.percentile(iris_versicolor['sepal_width'], np.arange(0, 100, 25)))
print("virginica Quantile: ", np.percentile(iris_virginica['sepal_width'], np.arange(0, 100, 25)))
print("\n90th Percentiles")
print("Setosa Percentile: ", np.percentile(iris_setosa['sepal_width'], 90))
print("Setosa corrupted Percentile: ", np.percentile(np.append(iris_setosa['sepal_width'], 50), 90))
print("versicolor Percentile: ", np.percentile(iris_versicolor['sepal_width'], 90))
print("virginica Percentile: ", np.percentile(iris_virginica['petal_length'], 90))
from statsmodels import robust
print("\nMedian Absolute Deviation")
print("Setosa MAD: ", robust.mad(iris_setosa['sepal_width']))
print("Setosa corrupted MAD: ", robust.mad(np.append(iris_setosa['sepal_width'], 50)))
print("versicolor MAD: ", robust.mad(iris_versicolor['sepal_width']))
print("virginica MAD: ", robust.mad(iris_virginica['sepal_width']))
# Out:
# Setosa mean:  3.428
# Setosa corrupted mean:  4.341176470588235
# versicolor mean:  2.7700000000000005
# virginica mean:  2.974
#
# Setosa variance:  0.14081600000000002
# Setosa corrupted variance:  41.83261822376009
# versicolor variance:  0.09650000000000002
# virginica variance:  0.10192399999999999
#
# Setosa std:  0.37525458025186054
# Setosa corrupted std:  6.467814022044859
# versicolor std:  0.31064449134018135
# virginica std:  0.3192553836664309
# Median:
# Setosa Median:  3.4
# Setosa corrupted Median:  3.4
# versicolor Median:  2.8
# virginica Median:  3.0
#
# Quantiles: [0, 25, 50, 75]
# Setosa Quantile:  [2.3   3.2   3.4   3.675]
# Setosa corrupted Quantile:  [2.3 3.2 3.4 3.7]
# versicolor Quantile:  [2.    2.525 2.8   3.   ]
# virginica Quantile:  [2.2   2.8   3.    3.175]
#
# 90th Percentiles
# Setosa Percentile:  3.9
# Setosa corrupted Percentile:  3.9
# versicolor Percentile:  3.1100000000000003
# virginica Percentile:  6.31
#
# Median Absolute Deviation
# ...
